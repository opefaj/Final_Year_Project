# %%
# Load required files.
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np

regression_dhs = "CDR_Data_IC/Regression/DHS/"
regression_cdr = "CDR_Data_IC/Regression/CDR/"
malaria_path = "IC_DHS/cihr62sv/"
aids_path = "IC_DHS/ciar61sv/"
wha_path = "IC_DHS/ciir62sv/"
cm_path = "IC_DHS/cibr62sv/"
cdr_path = "CDR_Data_IC/"

activity_admin_1 = pd.read_csv(cdr_path + "Activity/activity_admin_1.csv")
activity_admin_2 = pd.read_csv(cdr_path + "Activity/activity_admin_2.csv")
activity_admin_3 = pd.read_csv(cdr_path + "Activity/activity_admin_3.csv")

introversion_admin_1 = pd.read_csv(cdr_path + "Introversion/introversion_admin_1.csv")
introversion_admin_2 = pd.read_csv(cdr_path + "Introversion/introversion_admin_2.csv")
introversion_admin_3 = pd.read_csv(cdr_path + "Introversion/introversion_admin_3.csv")

entropy_admin_1 = pd.read_csv(cdr_path + "Network_Advantage/entropy_admin_1.csv")
entropy_admin_2 = pd.read_csv(cdr_path + "Network_Advantage/entropy_admin_2.csv")
entropy_admin_3 = pd.read_csv(cdr_path + "Network_Advantage/entropy_admin_3.csv")

meddegree_admin_1 = pd.read_csv(cdr_path + "Network_Advantage/meddegree_admin_1.csv")
meddegree_admin_2 = pd.read_csv(cdr_path + "Network_Advantage/meddegree_admin_2.csv")
meddegree_admin_3 = pd.read_csv(cdr_path + "Network_Advantage/meddegree_admin_3.csv")

gresidual_admin_1 = pd.read_csv(cdr_path + "Gravity_Residual/gresidual_admin_1.csv")
gresidual_admin_2 = pd.read_csv(cdr_path + "Gravity_Residual/gresidual_admin_2.csv")
gresidual_admin_3 = pd.read_csv(cdr_path + "Gravity_Residual/gresidual_admin_3.csv")

aids_admin_1 = pd.read_csv(aids_path + "aids_vor_aggregate_1.csv")
aids_admin_2 = pd.read_csv(aids_path + "aids_vor_aggregate_2.csv")
aids_admin_3 = pd.read_csv(aids_path + "aids_vor_aggregate_3.csv")

cm_admin_1 = pd.read_csv(cm_path + "cm_vor_aggregate_1.csv")
cm_admin_2 = pd.read_csv(cm_path + "cm_vor_aggregate_2.csv")
cm_admin_3 = pd.read_csv(cm_path + "cm_vor_aggregate_3.csv")

malaria_admin_1 = pd.read_csv(malaria_path + "malaria_vor_aggregate_1.csv")
malaria_admin_2 = pd.read_csv(malaria_path + "malaria_vor_aggregate_2.csv")
malaria_admin_3 = pd.read_csv(malaria_path + "malaria_vor_aggregate_3.csv")

wha_admin_1 = pd.read_csv(wha_path + "wha_vor_aggregate_1.csv")
wha_admin_2 = pd.read_csv(wha_path + "wha_vor_aggregate_2.csv")
wha_admin_3 = pd.read_csv(wha_path + "wha_vor_aggregate_3.csv")

# %%
# ACTIVITY. Normalize using square root and standardize using z-score.
activity_admin_1['Activity'] = np.sqrt(activity_admin_1['Activity'])
activity_zscore_1 = stats.zscore(activity_admin_1['Activity'].values)
norm_activity_1 = pd.DataFrame(columns=["Region", "Activity"])
norm_activity_1["Region"] =  activity_admin_1['Region']
norm_activity_1["Activity"] =  activity_zscore_1

activity_admin_2['Activity'] = np.sqrt(activity_admin_2['Activity'])
activity_zscore_2 = stats.zscore(activity_admin_2['Activity'].values)
norm_activity_2 = pd.DataFrame(columns=["Region", "Activity"])
norm_activity_2["Region"] =  activity_admin_2['Region']
norm_activity_2["Activity"] =  activity_zscore_2

activity_admin_3['Activity'] = np.sqrt(activity_admin_3['Activity'])
activity_zscore_3 = stats.zscore(activity_admin_3['Activity'].values)
norm_activity_3 = pd.DataFrame(columns=["Region", "Activity"])
norm_activity_3["Region"] =  activity_admin_3['Region']
norm_activity_3["Activity"] =  activity_zscore_3

# INTROVERSION. Normalize using square root and standardize using z-score.
introversion_admin_1['avg_introversion'] = np.sqrt(introversion_admin_1['avg_introversion'])
introversion_zscore_1 = stats.zscore(introversion_admin_1['avg_introversion'].values)
norm_introversion_1 = pd.DataFrame(columns=["Region", "avg_introversion"])
norm_introversion_1["Region"] =  introversion_admin_1['Region']
norm_introversion_1["avg_introversion"] =  introversion_zscore_1

introversion_admin_2['avg_introversion'] = np.sqrt(introversion_admin_2['avg_introversion'])
introversion_zscore_2 = stats.zscore(introversion_admin_2['avg_introversion'].values)
norm_introversion_2 = pd.DataFrame(columns=["Region", "avg_introversion"])
norm_introversion_2["Region"] =  introversion_admin_2['Region']
norm_introversion_2["avg_introversion"] =  introversion_zscore_2

introversion_admin_3['avg_introversion'] = np.sqrt(introversion_admin_3['avg_introversion'])
introversion_zscore_3 = stats.zscore(introversion_admin_3['avg_introversion'].values)
norm_introversion_3 = pd.DataFrame(columns=["Region", "avg_introversion"])
norm_introversion_3["Region"] =  introversion_admin_3['Region']
norm_introversion_3["avg_introversion"] =  introversion_zscore_3

# ENTROPY. Normalize using square root and standardize using z-score.
entropy_admin_1['normalised_entropy'] = np.sqrt(entropy_admin_1['normalised_entropy'])
entropy_zscore_1 = stats.zscore(entropy_admin_1['normalised_entropy'].values)
norm_entropy_1 = pd.DataFrame(columns=["Region", "normalised_entropy"])
norm_entropy_1["Region"] =  entropy_admin_1['Region']
norm_entropy_1["normalised_entropy"] =  entropy_zscore_1

entropy_admin_2['normalised_entropy'] = np.sqrt(entropy_admin_2['normalised_entropy'])
entropy_zscore_2 = stats.zscore(entropy_admin_2['normalised_entropy'].values)
norm_entropy_2 = pd.DataFrame(columns=["Region", "normalised_entropy"])
norm_entropy_2["Region"] =  entropy_admin_2['Region']
norm_entropy_2["normalised_entropy"] =  entropy_zscore_2

entropy_admin_3['normalised_entropy'] = np.sqrt(entropy_admin_3['normalised_entropy'])
entropy_zscore_3 = stats.zscore(entropy_admin_3['normalised_entropy'].values)
norm_entropy_3 = pd.DataFrame(columns=["Region", "normalised_entropy"])
norm_entropy_3["Region"] =  entropy_admin_3['Region']
norm_entropy_3["normalised_entropy"] =  entropy_zscore_3

# MEDIAN DEGREE. Normalize using square root and standardize using z-score.
meddegree_admin_1['medDegree'] = np.sqrt(meddegree_admin_1['medDegree'])
meddegree_zscore_1 = stats.zscore(meddegree_admin_1['medDegree'].values)
norm_meddegree_1 = pd.DataFrame(columns=["Region", "medDegree"])
norm_meddegree_1["Region"] =  meddegree_admin_1['Region']
norm_meddegree_1["medDegree"] =  meddegree_zscore_1

meddegree_admin_2['medDegree'] = np.sqrt(meddegree_admin_2['medDegree'])
meddegree_zscore_2 = stats.zscore(meddegree_admin_2['medDegree'].values)
norm_meddegree_2 = pd.DataFrame(columns=["Region", "medDegree"])
norm_meddegree_2["Region"] =  meddegree_admin_2['Region']
norm_meddegree_2["medDegree"] =  meddegree_zscore_2

meddegree_admin_3['medDegree'] = np.sqrt(meddegree_admin_3['medDegree'])
meddegree_zscore_3 = stats.zscore(meddegree_admin_3['medDegree'].values)
norm_meddegree_3 = pd.DataFrame(columns=["Region", "medDegree"])
norm_meddegree_3["Region"] =  meddegree_admin_3['Region']
norm_meddegree_3["medDegree"] =  meddegree_zscore_3

# GRAVITY RESIDUAL. Normalize using square root and standardize using z-score.
gresidual_admin_1['gResidual'] = np.sqrt(gresidual_admin_1['gResidual'])
gresidual_zscore_1 = stats.zscore(gresidual_admin_1['gResidual'].values)
norm_gresidual_1 = pd.DataFrame(columns=["Region", "gResidual"])
norm_gresidual_1["Region"] =  gresidual_admin_1['Region']
norm_gresidual_1["gResidual"] =  gresidual_zscore_1

gresidual_admin_2['gResidual'] = np.sqrt(gresidual_admin_2['gResidual'])
gresidual_zscore_2 = stats.zscore(gresidual_admin_2['gResidual'].values)
norm_gresidual_2 = pd.DataFrame(columns=["Region", "gResidual"])
norm_gresidual_2["Region"] =  gresidual_admin_2['Region']
norm_gresidual_2["gResidual"] =  gresidual_zscore_2

gresidual_admin_3['gResidual'] = np.sqrt(gresidual_admin_3['gResidual'])
gresidual_zscore_3 = stats.zscore(gresidual_admin_3['gResidual'].values)
norm_gresidual_3 = pd.DataFrame(columns=["Region", "gResidual"])
norm_gresidual_3["Region"] =  gresidual_admin_3['Region']
norm_gresidual_3["gResidual"] =  gresidual_zscore_3

# SAVE AS CSV.
norm_activity_1.to_csv(regression_cdr + "activity_1.csv", index=False)
norm_activity_2.to_csv(regression_cdr + "activity_2.csv", index=False)
norm_activity_3.to_csv(regression_cdr + "activity_3.csv", index=False)

norm_introversion_1.to_csv(regression_cdr + "introversion_1.csv", index=False)
norm_introversion_2.to_csv(regression_cdr + "introversion_2.csv", index=False)
norm_introversion_3.to_csv(regression_cdr + "introversion_3.csv", index=False)

norm_entropy_1.to_csv(regression_cdr + "entropy_1.csv", index=False)
norm_entropy_2.to_csv(regression_cdr + "entropy_2.csv", index=False)
norm_entropy_3.to_csv(regression_cdr + "entropy_3.csv", index=False)

norm_meddegree_1.to_csv(regression_cdr + "meddegree_1.csv", index=False)
norm_meddegree_2.to_csv(regression_cdr + "meddegree_2.csv", index=False)
norm_meddegree_3.to_csv(regression_cdr + "meddegree_3.csv", index=False)

norm_gresidual_1.to_csv(regression_cdr + "gresidual_1.csv", index=False)
norm_gresidual_2.to_csv(regression_cdr + "gresidual_2.csv", index=False)
norm_gresidual_3.to_csv(regression_cdr + "gresidual_3.csv", index=False)

# %%
# Computing Kendall correlation between the Aids & (Activity, Network Advantage, Introversion)
# -------------------------------------------NORMALISATION OF AIDS DATA -----------------------------------------------
column_name = "Positive_HIV_Pop"
# Normalize using square root and standardize using z-score.
aids_admin_1[column_name] = np.sqrt(aids_admin_1[column_name])
aids_zscore_1 = stats.zscore(aids_admin_1[column_name].values)
norm_aids_1 = pd.DataFrame(columns=["Region", column_name])
norm_aids_1["Region"] =  aids_admin_1['Admin_Region_1']
norm_aids_1[column_name] =  aids_zscore_1

aids_admin_2[column_name] = np.sqrt(aids_admin_2[column_name])
aids_zscore_2 = stats.zscore(aids_admin_2[column_name].values)
norm_aids_2 = pd.DataFrame(columns=["Region", column_name])
norm_aids_2["Region"] =  aids_admin_2['Admin_Region_2']
norm_aids_2[column_name] =  aids_zscore_2

aids_admin_3[column_name] = np.sqrt(aids_admin_3[column_name])
aids_zscore_3 = stats.zscore(aids_admin_3[column_name].values)
norm_aids_3 = pd.DataFrame(columns=["Region", column_name])
norm_aids_3["Region"] =  aids_admin_3['Admin_Region_3']
norm_aids_3[column_name] =  aids_zscore_3

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------AIDS & ACTIVITY-----------------")
x, y = stats.pearsonr(aids_zscore_1, activity_zscore_1)
print("Admin 1 - (HIV row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_2, activity_zscore_2)
print("Admin 2 - (HIV row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_3, activity_zscore_3)
print("Admin 3 - (HIV row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------AIDS & GRAVITY RESIDUAL-----------------")
x, y = stats.pearsonr(aids_zscore_1, gresidual_zscore_1)
print("Admin 1 - (HIV row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_2, gresidual_zscore_2)
print("Admin 2 - (HIV row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_3, gresidual_zscore_3)
print("Admin 3 - (HIV row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------AIDS & INTROVERSION-----------------")
x, y = stats.pearsonr(aids_zscore_1, introversion_zscore_1)
print("Admin 1 - (HIV row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_2, introversion_zscore_2)
print("Admin 2 - (HIV row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_3, introversion_zscore_3)
print("Admin 3 - (HIV row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------AIDS & ENTROPY-----------------")
x, y = stats.pearsonr(aids_zscore_1, entropy_zscore_1)
print("Admin 1 - (HIV row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_2, entropy_zscore_2)
print("Admin 2 - (HIV row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_3, entropy_zscore_3)
print("Admin 3 - (HIV row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------AIDS & MED DEGREE-----------------")
x, y = stats.pearsonr(aids_zscore_1, meddegree_zscore_1)
print("Admin 1 - (HIV row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_2, meddegree_zscore_2)
print("Admin 2 - (HIV row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_zscore_3, meddegree_zscore_3)
print("Admin 3 - (HIV row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()

# -----SAVE AS CSV-----
norm_aids_1.to_csv(regression_dhs + "aids_1.csv", index=False)
norm_aids_2.to_csv(regression_dhs + "aids_2.csv", index=False)
norm_aids_3.to_csv(regression_dhs + "aids_3.csv", index=False)
# Out:
# ---------------------AIDS & ACTIVITY-----------------
# Admin 1 - (HIV row count VOR, Activity): 0.763092835561 P Value: 0.000144481140256
# Admin 2 - (HIV row count VOR, Activity): 0.65050850351 P Value: 3.16197023989e-07
# Admin 3 - (HIV row count VOR, Activity): 0.734310312027 P Value: 1.29612109843e-32
#
# ---------------------AIDS & GRAVITY RESIDUAL-----------------
# Admin 1 - (HIV row count VOR, Gravity Residual): -0.434352775562 P Value: 0.0631344875745
# Admin 2 - (HIV row count VOR, Gravity Residual): -0.427463813556 P Value: 0.00195983645205
# Admin 3 - (HIV row count VOR, Gravity Residual): -0.258895676101 P Value: 0.000373180163266
#
# ---------------------AIDS & INTROVERSION-----------------
# Admin 1 - (HIV row count VOR, Introversion): -0.679764501789 P Value: 0.00136585432248
# Admin 2 - (HIV row count VOR, Introversion): -0.461431154766 P Value: 0.000744134201786
# Admin 3 - (HIV row count VOR, Introversion): -0.174363402278 P Value: 0.0176090803929
#
# ...

# %%
# Computing Kendall correlation between the Child Mortality & (Activity, Network Advantage, Introversion)

# -------------------------------------NORMALISATION OF CHILD MORTALITY DATA -----------------------------------------------
column_name = "CM_Pop_Count"
# Normalize using square root and standardize using z-score.
cm_admin_1[column_name] = np.sqrt(cm_admin_1[column_name])
cm_zscore_1 = stats.zscore(cm_admin_1[column_name].values)
norm_cm_1 = pd.DataFrame(columns=["Region", column_name])
norm_cm_1["Region"] =  cm_admin_1['Admin_Region_1']
norm_cm_1[column_name] =  cm_zscore_1

cm_admin_2[column_name] = np.sqrt(cm_admin_2[column_name])
cm_zscore_2 = stats.zscore(cm_admin_2[column_name].values)
norm_cm_2 = pd.DataFrame(columns=["Region", column_name])
norm_cm_2["Region"] =  cm_admin_2['Admin_Region_2']
norm_cm_2[column_name] =  cm_zscore_2

cm_admin_3[column_name] = np.sqrt(cm_admin_3[column_name])
cm_zscore_3 = stats.zscore(cm_admin_3[column_name].values)
norm_cm_3 = pd.DataFrame(columns=["Region", column_name])
norm_cm_3["Region"] =  cm_admin_3['Admin_Region_3']
norm_cm_3[column_name] =  cm_zscore_3

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------CM & ACTIVITY-----------------")
x, y = stats.pearsonr(cm_zscore_1, activity_zscore_1)
print("Admin 1 - (CM row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_2, activity_zscore_2)
print("Admin 2 - (CM row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_3, activity_zscore_3)
print("Admin 3 - (CM row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------CM & GRAVITY RESIDUAL-----------------")
x, y = stats.pearsonr(cm_zscore_1, gresidual_zscore_1)
print("Admin 1 - (CM row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_2, gresidual_zscore_2)
print("Admin 2 - (CM row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_3, gresidual_zscore_3)
print("Admin 3 - (CM row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------CM & INTROVERSION-----------------")
x, y = stats.pearsonr(cm_zscore_1, introversion_zscore_1)
print("Admin 1 - (CM row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_2, introversion_zscore_2)
print("Admin 2 - (CM row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_3, introversion_zscore_3)
print("Admin 3 - (CM row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------CM & ENTROPY-----------------")
x, y = stats.pearsonr(cm_zscore_1, entropy_zscore_1)
print("Admin 1 - (CM row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_2, entropy_zscore_2)
print("Admin 2 - (CM row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_3, entropy_zscore_3)
print("Admin 3 - (CM row count VOR, Entropy): " +  str(x) + " P Value: " + str(y) )
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------CM & MED DEGREE-----------------")
x, y = stats.pearsonr(cm_zscore_1, meddegree_zscore_1)
print("Admin 1 - (CM row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_2, meddegree_zscore_2)
print("Admin 2 - (CM row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_zscore_3, meddegree_zscore_3)
print("Admin 3 - (CM row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()

# -----SAVE AS CSV-----
norm_cm_1.to_csv(regression_dhs + "cm_1.csv", index=False)
norm_cm_2.to_csv(regression_dhs + "cm_2.csv", index=False)
norm_cm_3.to_csv(regression_dhs + "cm_3.csv", index=False)
# Out:
# ---------------------CM & ACTIVITY-----------------
# Admin 1 - (CM row count VOR, Activity): 0.289154956212 P Value: 0.229871516618
# Admin 2 - (CM row count VOR, Activity): 0.409983522516 P Value: 0.00310764309371
# Admin 3 - (CM row count VOR, Activity): 0.415989562376 P Value: 3.88991515915e-09
#
# ---------------------CM & GRAVITY RESIDUAL-----------------
# Admin 1 - (CM row count VOR, Gravity Residual): 0.0199524339607 P Value: 0.935383225107
# Admin 2 - (CM row count VOR, Gravity Residual): 0.0211833332285 P Value: 0.883908360049
# Admin 3 - (CM row count VOR, Gravity Residual): -0.185368726379 P Value: 0.0115326692968
#
# ---------------------CM & INTROVERSION-----------------
# Admin 1 - (CM row count VOR, Introversion): -0.212018118309 P Value: 0.383539560873
# Admin 2 - (CM row count VOR, Introversion): -0.283707970856 P Value: 0.0458674119996
# Admin 3 - (CM row count VOR, Introversion): -0.217668878952 P Value: 0.00291729605325
#
# ...

# %%
# Computing Kendall correlation between the Malaria & (Activity, Network Advantage, Introversion)
# -------------------------------------------NORMALISATION OF MALARIA DATA -----------------------------------------------
column_name = "Lab_Pop_Count"
# Normalize using square root and standardize using z-score.
malaria_admin_1[column_name] = np.sqrt(malaria_admin_1[column_name])
malaria_zscore_1 = stats.zscore(malaria_admin_1[column_name].values)
norm_mal_lab_1 = pd.DataFrame(columns=["Region", column_name])
norm_mal_lab_1["Region"] =  malaria_admin_1['Admin_Region_1']
norm_mal_lab_1[column_name] =  malaria_zscore_1

malaria_admin_2[column_name] = np.sqrt(malaria_admin_2[column_name])
malaria_zscore_2 = stats.zscore(malaria_admin_2[column_name].values)
norm_mal_lab_2 = pd.DataFrame(columns=["Region", column_name])
norm_mal_lab_2["Region"] =  malaria_admin_2['Admin_Region_2']
norm_mal_lab_2[column_name] =  malaria_zscore_2

malaria_admin_3[column_name] = np.sqrt(malaria_admin_3[column_name])
malaria_zscore_3 = stats.zscore(malaria_admin_3[column_name].values)
norm_mal_lab_3 = pd.DataFrame(columns=["Region", column_name])
norm_mal_lab_3["Region"] =  malaria_admin_3['Admin_Region_3']
norm_mal_lab_3[column_name] =  malaria_zscore_3

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & ACTIVITY-----------------")
x, y = stats.pearsonr(malaria_zscore_1, activity_zscore_1)
print("Admin 1 - (Lab Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_2, activity_zscore_2)
print("Admin 2 - (Lab Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_3, activity_zscore_3)
print("Admin 3 - (Lab Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & GRAVITY RESIDUAL-----------------")
x, y = stats.pearsonr(malaria_zscore_1, gresidual_zscore_1)
print("Admin 1 - (Lab Test row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_2, gresidual_zscore_2)
print("Admin 2 - (Lab Test row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_3, gresidual_zscore_3)
print("Admin 3 - (Lab Test row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & INTROVERSION-----------------")
x, y = stats.pearsonr(malaria_zscore_1, introversion_zscore_1)
print("Admin 1 - (Lab Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_2, introversion_zscore_2)
print("Admin 2 - (Lab Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_3, introversion_zscore_3)
print("Admin 3 - (Lab Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & ENTROPY-----------------")
x, y = stats.pearsonr(malaria_zscore_1, entropy_zscore_1)
print("Admin 1 - (Lab Test row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_2, entropy_zscore_2)
print("Admin 2 - (Lab Test row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_3, entropy_zscore_3)
print("Admin 3 - (Lab Test row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & MED DEGREE-----------------")
x, y = stats.pearsonr(malaria_zscore_1, meddegree_zscore_1)
print("Admin 1 - (Lab Test row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_2, meddegree_zscore_2)
print("Admin 2 - (Lab Test row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_zscore_3, meddegree_zscore_3)
print("Admin 3 - (Lab Test row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()

# -----SAVE AS CSV-----
norm_mal_lab_1.to_csv(regression_dhs + "malaria_lab_1.csv", index=False)
norm_mal_lab_2.to_csv(regression_dhs + "malaria_lab_2.csv", index=False)
norm_mal_lab_3.to_csv(regression_dhs + "malaria_lab_3.csv", index=False)
# Out:
# ---------------------LAB TEST & ACTIVITY-----------------
# Admin 1 - (Lab Test row count VOR, Activity): 0.228112676719 P Value: 0.347585718575
# Admin 2 - (Lab Test row count VOR, Activity): 0.170757326026 P Value: 0.235768904973
# Admin 3 - (Lab Test row count VOR, Activity): 0.436261226758 P Value: 5.38750723557e-10
#
# ---------------------LAB TEST & GRAVITY RESIDUAL-----------------
# Admin 1 - (Lab Test row count VOR, Gravity Residual): -0.301491718668 P Value: 0.209699270558
# Admin 2 - (Lab Test row count VOR, Gravity Residual): -0.371466825549 P Value: 0.00790718465736
# Admin 3 - (Lab Test row count VOR, Gravity Residual): -0.123595623465 P Value: 0.0937145322641
#
# ---------------------LAB TEST & INTROVERSION-----------------
# Admin 1 - (Lab Test row count VOR, Introversion): -0.273935313253 P Value: 0.256429468358
# Admin 2 - (Lab Test row count VOR, Introversion): -0.174752832182 P Value: 0.224823584728
# ...

# %%
# -------------------------------------------NORMALISATION OF MALARIA DATA -----------------------------------------------
column_name = "Rapid_Pop_Count"
# Normalize using square root and standardize using z-score.
malaria_admin_1[column_name] = np.sqrt(malaria_admin_1[column_name])
malariar_zscore_1 = stats.zscore(malaria_admin_1[column_name].values)
norm_mal_rapid_1 = pd.DataFrame(columns=["Region", column_name])
norm_mal_rapid_1["Region"] =  malaria_admin_1['Admin_Region_1']
norm_mal_rapid_1[column_name] =  malariar_zscore_1

malaria_admin_2[column_name] = np.sqrt(malaria_admin_2[column_name])
malariar_zscore_2 = stats.zscore(malaria_admin_2[column_name].values)
norm_mal_rapid_2 = pd.DataFrame(columns=["Region", column_name])
norm_mal_rapid_2["Region"] =  malaria_admin_2['Admin_Region_2']
norm_mal_rapid_2[column_name] =  malariar_zscore_2

malaria_admin_3[column_name] = np.sqrt(malaria_admin_3[column_name])
malariar_zscore_3 = stats.zscore(malaria_admin_3[column_name].values)
norm_mal_rapid_3 = pd.DataFrame(columns=["Region", column_name])
norm_mal_rapid_3["Region"] =  malaria_admin_3['Admin_Region_3']
norm_mal_rapid_3[column_name] =  malariar_zscore_3

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & ACTIVITY-----------------")
x, y = stats.pearsonr(malariar_zscore_1, activity_zscore_1)
print("Admin 1 - (Rapid Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_2, activity_zscore_2)
print("Admin 2 - (Rapid Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_3, activity_zscore_3)
print("Admin 3 - (Rapid Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------RAPID TEST & GRAVITY RESIDUAL-----------------")
x, y = stats.pearsonr(malariar_zscore_1, gresidual_zscore_1)
print("Admin 1 - (Rapid Test row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_2, gresidual_zscore_2)
print("Admin 2 - (Rapid Test row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_3, gresidual_zscore_3)
print("Admin 3 - (Rapid Test row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & INTROVERSION-----------------")
x, y = stats.pearsonr(malariar_zscore_1, introversion_zscore_1)
print("Admin 1 - (Rapid Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_2, introversion_zscore_2)
print("Admin 2 - (Rapid Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_3, introversion_zscore_3)
print("Admin 3 - (Rapid Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & ENTROPY-----------------")
x, y = stats.pearsonr(malariar_zscore_1, entropy_zscore_1)
print("Admin 1 - (Rapid Test row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_2, entropy_zscore_2)
print("Admin 2 - (Rapid Test row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_3, entropy_zscore_3)
print("Admin 3 - (Rapid Test row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & MED DEGREE-----------------")
x, y = stats.pearsonr(malariar_zscore_1, meddegree_zscore_1)
print("Admin 1 - (Rapid Test row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_2, meddegree_zscore_2)
print("Admin 2 - (Rapid Test row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malariar_zscore_3, meddegree_zscore_3)
print("Admin 3 - (Rapid Test row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()

# -----SAVE AS CSV-----
norm_mal_rapid_1.to_csv(regression_dhs + "malaria_rapid_1.csv", index=False)
norm_mal_rapid_2.to_csv(regression_dhs + "malaria_rapid_2.csv", index=False)
norm_mal_rapid_3.to_csv(regression_dhs + "malaria_rapid_3.csv", index=False)
# Out:
# ---------------------MALARIA RAPID TEST & ACTIVITY-----------------
# Admin 1 - (Rapid Test row count VOR, Activity): 0.165273032278 P Value: 0.49893002824
# Admin 2 - (Rapid Test row count VOR, Activity): 0.218439418775 P Value: 0.127507911494
# Admin 3 - (Rapid Test row count VOR, Activity): 0.45612040226 P Value: 6.81670891325e-11
#
# ---------------------RAPID TEST & GRAVITY RESIDUAL-----------------
# Admin 1 - (Rapid Test row count VOR, Gravity Residual): -0.199989426294 P Value: 0.411706251103
# Admin 2 - (Rapid Test row count VOR, Gravity Residual): -0.27002219713 P Value: 0.0579010159344
# Admin 3 - (Rapid Test row count VOR, Gravity Residual): -0.173878799205 P Value: 0.0179311208633
#
# ---------------------MALARIA RAPID TEST & INTROVERSION-----------------
# Admin 1 - (Rapid Test row count VOR, Introversion): -0.133102950437 P Value: 0.586977440075
# Admin 2 - (Rapid Test row count VOR, Introversion): -0.15159648049 P Value: 0.29329296389
# ...

# %%
# Computing Kendall correlation between the Womens' Access To Health & (Activity, Network Advantage, Introversion)
# -------------------------------------------NORMALISATION OF WHA DATA -----------------------------------------------
column_name = "Care_Pop_Count"
# Normalize using square root and standardize using z-score.
wha_admin_1[column_name] = np.sqrt(wha_admin_1[column_name])
wha_zscore_1 = stats.zscore(wha_admin_1[column_name].values)
norm_wha_care_1 = pd.DataFrame(columns=["Region", column_name])
norm_wha_care_1["Region"] =  wha_admin_1['Admin_Region_1']
norm_wha_care_1[column_name] =  wha_zscore_1

wha_admin_2[column_name] = np.sqrt(wha_admin_2[column_name])
wha_zscore_2 = stats.zscore(wha_admin_2[column_name].values)
norm_wha_care_2 = pd.DataFrame(columns=["Region", column_name])
norm_wha_care_2["Region"] =  wha_admin_2['Admin_Region_2']
norm_wha_care_2[column_name] =  wha_zscore_2

wha_admin_3[column_name] = np.sqrt(wha_admin_3[column_name])
wha_zscore_3 = stats.zscore(wha_admin_3[column_name].values)
norm_wha_care_3 = pd.DataFrame(columns=["Region", column_name])
norm_wha_care_3["Region"] =  wha_admin_3['Admin_Region_3']
norm_wha_care_3[column_name] =  wha_zscore_3

print("---------------------WHA & ACTIVITY-----------------")
x, y = stats.pearsonr(wha_zscore_1, activity_zscore_1)
print("Admin 1 - (WHA row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_2, activity_zscore_2)
print("Admin 2 - (WHA row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_3, activity_zscore_3)
print("Admin 3 - (WHA row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------WHA & GRAVITY RESIDUAL-----------------")
x, y = stats.pearsonr(wha_zscore_1, gresidual_zscore_1)
print("Admin 1 - (WHA row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_2, gresidual_zscore_2)
print("Admin 2 - (WHA row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_3, gresidual_zscore_3)
print("Admin 3 - (WHA row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA & INTROVERSION-----------------")
x, y = stats.pearsonr(wha_zscore_1, introversion_zscore_1)
print("Admin 1 - (WHA row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_2, introversion_zscore_2)
print("Admin 2 - (WHA row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_3, introversion_zscore_3)
print("Admin 3 - (WHA row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA & ENTROPY-----------------")
x, y = stats.pearsonr(wha_zscore_1, entropy_zscore_1)
print("Admin 1 - (WHA row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_2, entropy_zscore_2)
print("Admin 2 - (WHA row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_3, entropy_zscore_3)
print("Admin 3 - (WHA row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA & MED DEGREE-----------------")
x, y = stats.pearsonr(wha_zscore_1, meddegree_zscore_1)
print("Admin 1 - (WHA row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_2, meddegree_zscore_2)
print("Admin 2 - (WHA row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(wha_zscore_3, meddegree_zscore_3)
print("Admin 3 - (WHA row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()

# -----SAVE AS CSV-----
norm_wha_care_1.to_csv(regression_dhs + "wha_care_1.csv", index=False)
norm_wha_care_2.to_csv(regression_dhs + "wha_care_2.csv", index=False)
norm_wha_care_3.to_csv(regression_dhs + "wha_care_3.csv", index=False)
# Out:
# ---------------------WHA & ACTIVITY-----------------
# Admin 1 - (WHA row count VOR, Activity): 0.708484718563 P Value: 0.000686008262027
# Admin 2 - (WHA row count VOR, Activity): 0.68000150727 P Value: 5.59680555915e-08
# Admin 3 - (WHA row count VOR, Activity): 0.763087890068 P Value: 1.56559870535e-36
#
# ---------------------WHA & GRAVITY RESIDUAL-----------------
# Admin 1 - (WHA row count VOR, Gravity Residual): -0.422343121327 P Value: 0.0716487586557
# Admin 2 - (WHA row count VOR, Gravity Residual): -0.439563741251 P Value: 0.00140386021036
# Admin 3 - (WHA row count VOR, Gravity Residual): -0.329138322458 P Value: 4.77286074848e-06
#
# ---------------------WHA & INTROVERSION-----------------
# Admin 1 - (WHA row count VOR, Introversion): -0.602147913754 P Value: 0.00637099960703
# Admin 2 - (WHA row count VOR, Introversion): -0.482281369711 P Value: 0.00039014481431
# Admin 3 - (WHA row count VOR, Introversion): -0.168125627675 P Value: 0.0221629019038
#
# ...

# %%
# -------------------------------------------NORMALISATION OF WHA DATA -----------------------------------------------
column_name = "Zero_Pop_Count"
# Normalize using square root and standardize using z-score.
wha_admin_1[column_name] = np.sqrt(wha_admin_1[column_name])
whaz_zscore_1 = stats.zscore(wha_admin_1[column_name].values)
norm_wha_nocare_1 = pd.DataFrame(columns=["Region", column_name])
norm_wha_nocare_1["Region"] =  wha_admin_1['Admin_Region_1']
norm_wha_nocare_1[column_name] =  whaz_zscore_1

wha_admin_2[column_name] = np.sqrt(wha_admin_2[column_name])
whaz_zscore_2 = stats.zscore(wha_admin_2[column_name].values)
norm_wha_nocare_2 = pd.DataFrame(columns=["Region", column_name])
norm_wha_nocare_2["Region"] =  wha_admin_2['Admin_Region_2']
norm_wha_nocare_2[column_name] =  whaz_zscore_2

wha_admin_3[column_name] = np.sqrt(wha_admin_3[column_name])
whaz_zscore_3 = stats.zscore(wha_admin_3[column_name].values)
norm_wha_nocare_3 = pd.DataFrame(columns=["Region", column_name])
norm_wha_nocare_3["Region"] =  wha_admin_3['Admin_Region_3']
norm_wha_nocare_3[column_name] =  whaz_zscore_3

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & ACTIVITY-----------------")
x, y = stats.pearsonr(whaz_zscore_1, activity_zscore_1)
print("Admin 1 - (WHA row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_2, activity_zscore_2)
print("Admin 2 - (WHA row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_3, activity_zscore_3)
print("Admin 3 - (WHA row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & GRAVITY RESIDUAL-----------------")
x, y = stats.pearsonr(whaz_zscore_1, gresidual_zscore_1)
print("Admin 1 - (WHA row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_2, gresidual_zscore_2)
print("Admin 2 - (WHA row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_3, gresidual_zscore_3)
print("Admin 3 - (WHA row count VOR, Gravity Residual): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & INTROVERSION-----------------")
x, y = stats.pearsonr(whaz_zscore_1, introversion_zscore_1)
print("Admin 1 - (WHA row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_2, introversion_zscore_2)
print("Admin 2 - (WHA row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_3, introversion_zscore_3)
print("Admin 3 - (WHA row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & ENTROPY-----------------")
x, y = stats.pearsonr(whaz_zscore_1, entropy_zscore_1)
print("Admin 1 - (WHA row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_2, entropy_zscore_2)
print("Admin 2 - (WHA row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

whaz_admin_3_new = wha_admin_3[wha_admin_3['Admin_Region_3'].isin(entropy_admin_3['Region'])]
whaz_zscore_3 = stats.zscore(whaz_admin_3_new[column_name].values)

x, y = stats.pearsonr(whaz_zscore_3, entropy_zscore_3)
print("Admin 3 - (WHA row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & MED DEGREE-----------------")
x, y = stats.pearsonr(whaz_zscore_1, meddegree_zscore_1)
print("Admin 1 - (WHA row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_2, meddegree_zscore_2)
print("Admin 2 - (WHA row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(whaz_zscore_3, meddegree_zscore_3)
print("Admin 3 - (WHA row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()

# -----SAVE AS CSV-----
norm_wha_nocare_1.to_csv(regression_dhs + "wha_nocare_1.csv", index=False)
norm_wha_nocare_2.to_csv(regression_dhs + "wha_nocare_2.csv", index=False)
norm_wha_nocare_3.to_csv(regression_dhs + "wha_nocare_3.csv", index=False)
# Out:
# ---------------------WHA ZERO CARE & ACTIVITY-----------------
# Admin 1 - (WHA row count VOR, Activity): -0.149690083276 P Value: 0.540769590858
# Admin 2 - (WHA row count VOR, Activity): 0.0721063194396 P Value: 0.618751046727
# Admin 3 - (WHA row count VOR, Activity): 0.181422351202 P Value: 0.0134573927365
#
# ---------------------WHA ZERO CARE & GRAVITY RESIDUAL-----------------
# Admin 1 - (WHA row count VOR, Gravity Residual): 0.305132495843 P Value: 0.203976226876
# Admin 2 - (WHA row count VOR, Gravity Residual): 0.286395316351 P Value: 0.0437629933265
# Admin 3 - (WHA row count VOR, Gravity Residual): 0.123589274992 P Value: 0.0937315241696
#
# ---------------------WHA ZERO CARE & INTROVERSION-----------------
# Admin 1 - (WHA row count VOR, Introversion): 0.268125255675 P Value: 0.267057494935
# Admin 2 - (WHA row count VOR, Introversion): 0.17044744158 P Value: 0.236632796071
# Admin 3 - (WHA row count VOR, Introversion): 0.00676551264756 P Value: 0.927176143662
#
# ...
