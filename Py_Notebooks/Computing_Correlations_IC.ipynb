# %%
# RE DO THIS.
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np

malaria_path = "Cote D'Ivoire Data SPSS/cihr62sv/"
aids_path = "Cote D'Ivoire Data SPSS/ciar61sv/"
wha_path = "Cote D'Ivoire Data SPSS/ciir62sv/"
cm_path = "Cote D'Ivoire Data SPSS/cibr62sv/"
cdr_path = "CDR_Data_IC/"

activity_admin_1 = pd.read_csv(cdr_path + "Activity/activity_admin_1.csv")
activity_admin_2 = pd.read_csv(cdr_path + "Activity/activity_admin_2.csv")
activity_admin_3 = pd.read_csv(cdr_path + "Activity/activity_admin_3.csv")

introversion_admin_1 = pd.read_csv(cdr_path + "Introversion/introversion_admin_1.csv")
introversion_admin_2 = pd.read_csv(cdr_path + "Introversion/introversion_admin_2.csv")
introversion_admin_3 = pd.read_csv(cdr_path + "Introversion/introversion_admin_3.csv")

entropy_admin_1 = pd.read_csv(cdr_path + "Network_Advantage/entropy_admin_1.csv")
entropy_admin_2 = pd.read_csv(cdr_path + "Network_Advantage/entropy_admin_2.csv")
entropy_admin_3 = pd.read_csv(cdr_path + "Network_Advantage/entropy_admin_3.csv")

meddegree_admin_1 = pd.read_csv(cdr_path + "Network_Advantage/meddegree_admin_1.csv")
meddegree_admin_2 = pd.read_csv(cdr_path + "Network_Advantage/meddegree_admin_2.csv")
meddegree_admin_3 = pd.read_csv(cdr_path + "Network_Advantage/meddegree_admin_3.csv")

aids_admin_1 = pd.read_csv(aids_path + "aids_vor_aggregate_1.csv")
aids_admin_2 = pd.read_csv(aids_path + "aids_vor_aggregate_2.csv")
aids_admin_3 = pd.read_csv(aids_path + "aids_vor_aggregate_3.csv")

cm_admin_1 = pd.read_csv(cm_path + "cm_vor_aggregate_1.csv")
cm_admin_2 = pd.read_csv(cm_path + "cm_vor_aggregate_2.csv")
cm_admin_3 = pd.read_csv(cm_path + "cm_vor_aggregate_3.csv")

malaria_admin_1 = pd.read_csv(malaria_path + "malaria_vor_aggregate_1.csv")
malaria_admin_2 = pd.read_csv(malaria_path + "malaria_vor_aggregate_2.csv")
malaria_admin_3 = pd.read_csv(malaria_path + "malaria_vor_aggregate_3.csv")

wha_admin_1 = pd.read_csv(wha_path + "wha_vor_aggregate_1.csv")
wha_admin_2 = pd.read_csv(wha_path + "wha_vor_aggregate_2.csv")
wha_admin_3 = pd.read_csv(wha_path + "wha_vor_aggregate_3.csv")

# %%
# ACTIVITY
# Admin Region 1. SHOW A GRAPH FOR THE RESULT.
activity_counts_1 = activity_admin_1['Activity'].value_counts()
activity_counts_1.plot(kind="bar")
# plt.show()
print("Post-Normalisation")
activity_admin_1['Activity'] = np.sqrt(activity_admin_1['Activity'])
activity_zscore_1 = activity_admin_1['Activity'].values
print(stats.zscore(activity_zscore_1))

# Admin Region 2.
activity_counts_2 = activity_admin_2['Activity'].value_counts()
activity_counts_2.plot(kind="bar")
print("Post-Normalisation")
activity_admin_2['Activity'] = np.sqrt(activity_admin_2['Activity'])
activity_zscore_2 = activity_admin_2['Activity'].values
print(stats.zscore(activity_zscore_2))

# Admin Region 3.
activity_counts_3 = activity_admin_3['Activity'].value_counts()
activity_counts_3.plot(kind="bar")
print("Post-Normalisation")
activity_admin_3['Activity'] = np.sqrt(activity_admin_3['Activity'])
activity_zscore_3 = activity_admin_3['Activity'].values
print(stats.zscore(activity_zscore_3))
# Out:
# Post-Normalisation
# [ -1.00681550e-01  -1.79722862e+00   1.31410654e+00  -2.58489942e+00
#    1.45283166e-02   2.33848659e-01   5.94795086e-01   5.69403779e-01
#    2.26363359e+00   6.53903364e-02  -1.10058208e-01   2.74344862e-01
#    2.42878940e-01  -8.87215076e-02  -1.67085919e-03  -1.02289931e-01
#    5.24862937e-01  -9.63418514e-01  -3.48824434e-01]
# Post-Normalisation
# [ 0.28442614  0.34991837 -0.66531483  1.43472928  0.54065239  1.67776338
#   0.10557003 -1.41633115 -1.31364099 -1.02757772 -0.07677715  0.43575523
#   0.78399059  0.50900686  1.04704316  0.45503341  0.27305538  0.2069047
#   1.3922726   3.18884753 -1.14512945 -0.10749914  0.53546903 -0.07856579
#  -0.42389388 -0.0481545   0.56000722  1.11176676 -0.14701697  0.56088499
#  -0.07844973 -0.16955235 -0.73558198 -1.28966942 -0.28445968  0.49797372
#  -2.62689955  0.79914981 -0.2807461   0.9507494  -0.8907555   1.27992629
#  -1.78410965 -0.62870699 -0.99797751 -0.5195315  -0.605548    0.04986236
# ...

# %%
# INTROVERSION - RETURNING NAN, CHECK THIS.
# Admin 1.
introversion_1 = introversion_admin_1['avg_introversion']
introversion_counts_1 = introversion_1.value_counts()
print("Post-Normalisation")
introversion_admin_1['avg_introversion'] = np.sqrt(introversion_admin_1['avg_introversion'])
introversion_zscore_1 = introversion_admin_1['avg_introversion'].values
print(stats.zscore(introversion_zscore_1))
print()

# Admin 2.
introversion_2 = introversion_admin_2['avg_introversion']
print("Pre-Normalisation Admin Region 2")
introversion_counts_2 = introversion_2.value_counts()
print("Post-Normalisation")
introversion_admin_2['avg_introversion'] = np.sqrt(introversion_admin_2['avg_introversion'])
introversion_zscore_2 = introversion_admin_2['avg_introversion'].values
print(stats.zscore(introversion_zscore_2))
print()

# Admin 3. REMOVE THE VALUES WITH INFINITY OR NAN.
introversion_3 = introversion_admin_3['avg_introversion']
introversion_counts_3 = introversion_3.value_counts()
print("Post-Normalisation")
introversion_admin_3['avg_introversion'] = np.sqrt(introversion_admin_3['avg_introversion'])
introversion_zscore_3 = introversion_admin_3['avg_introversion'].values
print(stats.zscore(introversion_zscore_3))
print()
# Out:
# Post-Normalisation
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan]
#
# Pre-Normalisation Admin Region 2
# Post-Normalisation
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan]
#
# Post-Normalisation
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
# ...

# %%
# ENTROPY.
# Admin 1.
entropy_1 = entropy_admin_1['normalised_entropy']
entropy_counts_1 = entropy_1.value_counts()
print("Post-Normalisation")
entropy_admin_1['normalised_entropy'] = np.sqrt(entropy_admin_1['normalised_entropy'])
entropy_zscore_1 = entropy_admin_1['normalised_entropy'].values
print(stats.zscore(entropy_zscore_1))
print()

# Admin 2.
entropy_2 = entropy_admin_2['normalised_entropy']
entropy_counts_2 = entropy_2.value_counts()
print("Post-Normalisation")
entropy_admin_2['normalised_entropy'] = np.sqrt(entropy_admin_2['normalised_entropy'])
entropy_zscore_2 = entropy_admin_2['normalised_entropy'].values
print(stats.zscore(entropy_zscore_2))
print()

# Admin 3. REMOVE THE VALUES WITH INFINITY OR NAN.
entropy_3 = entropy_admin_3['normalised_entropy']
entropy_counts_3 = entropy_3.value_counts()
print("Post-Normalisation")
entropy_admin_3['normalised_entropy'] = np.sqrt(entropy_admin_3['normalised_entropy'])
entropy_zscore_3 = entropy_admin_3['normalised_entropy'].values
print(stats.zscore(entropy_zscore_3))
print()
# Out:
# Post-Normalisation
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan]
#
# Post-Normalisation
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan]
#
# Post-Normalisation
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
# ...

# %%
# MEDIAN DEGREE.
# Admin 1.
meddegree_1 = meddegree_admin_1['medDegree']
print("Pre-Normalisation")
meddegree_counts_1 = meddegree_1.value_counts()
meddegree_counts_1.plot(kind="bar")
# plt.show()

print("Post-Normalisation")
meddegree_admin_1['medDegree'] = np.sqrt(meddegree_admin_1['medDegree'])
meddegree_zscore_1 = meddegree_admin_1['medDegree'].values
print(stats.zscore(meddegree_zscore_1))
print()

# Admin 2.
meddegree_2 = meddegree_admin_2['medDegree']
print("Pre-Normalisation")
meddegree_counts_2 = meddegree_2.value_counts()
meddegree_counts_2.plot(kind="bar")
# plt.show()

print("Post-Normalisation")
meddegree_admin_2['medDegree'] = np.sqrt(meddegree_admin_2['medDegree'])
meddegree_zscore_2 = meddegree_admin_2['medDegree'].values
print(stats.zscore(meddegree_zscore_2))
print()

# Admin 3. REMOVE THE VALUES WITH INFINITY OR NAN.
meddegree_3 = meddegree_admin_3['medDegree']
print("Pre-Normalisation")
meddegree_counts_3 = meddegree_3.value_counts()
meddegree_counts_3.plot(kind="bar")
# plt.show()

print("Post-Normalisation")
meddegree_admin_3['medDegree'] = np.sqrt(meddegree_admin_3['medDegree'])
meddegree_zscore_3 = meddegree_admin_3['medDegree'].values
print(stats.zscore(meddegree_zscore_3))
print()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# Name: medDegree, dtype: float64
# Pre-Normalisation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-cec90a87d874> in <module>()
#       5 print("Pre-Normalisation")
#       6 meddegree_counts_1 = meddegree_1.value_counts()
# ----> 7 meddegree_counts_1.plot(kind="bar")
#       8 # plt.show()
#       9
#
# /usr/local/lib/python3.6/site-packages/pandas/tools/plotting.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3598                            colormap=colormap, table=table, yerr=yerr,
# ...

# %%
# Computing Kendall correlation between the Aids & (Activity, Network Advantage, Introversion)
aids_admin_1 = pd.read_csv(aids_path + "aids_vor_aggregate_1.csv")
aids_admin_2 = pd.read_csv(aids_path + "aids_vor_aggregate_2.csv")
aids_admin_3 = pd.read_csv(aids_path + "aids_vor_aggregate_3.csv")

# -------------------------------------------NORMALISATION OF AIDS DATA -----------------------------------------------
aids_admin_1['Positive_Row_Count'] = np.log(aids_admin_1['Positive_Row_Count'])
aids_zscore_1 = aids_admin_1['Positive_Row_Count'].values

aids_admin_2['Positive_Row_Count'] = np.log(aids_admin_2['Positive_Row_Count'])
aids_zscore_2 = aids_admin_2['Positive_Row_Count'].values

aids_admin_3['Positive_Row_Count'] = np.log(aids_admin_3['Positive_Row_Count'])
aids_zscore_3 = aids_admin_3['Positive_Row_Count'].values

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------AIDS & ACTIVITY-----------------")
x, y = stats.pearsonr(aids_admin_1['Positive_Row_Count'], activity_admin_1['Activity'])
print("Admin 1 - (HIV row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_2['Positive_Row_Count'], activity_admin_2['Activity'])
print("Admin 2 - (HIV row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_3['Positive_Row_Count'], activity_admin_3['Activity'])
print("Admin 3 - (HIV row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------AIDS & INTROVERSION-----------------")
x, y = stats.pearsonr(aids_admin_1['Positive_Row_Count'], introversion_admin_1['avg_introversion'])
print("Admin 1 - (HIV row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_2['Positive_Row_Count'], introversion_admin_2['avg_introversion'])
print("Admin 2 - (HIV row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_3['Positive_Row_Count'], introversion_admin_3['avg_introversion'])
print("Admin 3 - (HIV row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------AIDS & ENTROPY-----------------")
x, y = stats.pearsonr(aids_admin_1['Positive_Row_Count'], entropy_admin_1['normalised_entropy'])
print("Admin 1 - (HIV row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_2['Positive_Row_Count'], entropy_admin_2['normalised_entropy'])
print("Admin 2 - (HIV row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_3['Positive_Row_Count'], entropy_admin_3['normalised_entropy'])
print("Admin 3 - (HIV row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------AIDS & MED DEGREE-----------------")
x, y = stats.pearsonr(aids_admin_1['Positive_Row_Count'], meddegree_admin_1['medDegree'])
print("Admin 1 - (HIV row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_2['Positive_Row_Count'], meddegree_admin_2['medDegree'])
print("Admin 2 - (HIV row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(aids_admin_3['Positive_Row_Count'], meddegree_admin_3['medDegree'])
print("Admin 3 - (HIV row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()
# Out:
# ---------------------AIDS & ACTIVITY-----------------
# Admin 1 - (HIV row count VOR, Activity): 0.635605324312 P Value: 0.00344794641595
# Admin 2 - (HIV row count VOR, Activity): 0.567078900087 P Value: 1.75648088292e-05
# Admin 3 - (HIV row count VOR, Activity): nan P Value: 1.0
#
# ---------------------AIDS & INTROVERSION-----------------
# Admin 1 - (HIV row count VOR, Introversion): -0.501436855385 P Value: 0.0287234316055
# Admin 2 - (HIV row count VOR, Introversion): -0.304592309056 P Value: 0.0314990560288
# Admin 3 - (HIV row count VOR, Introversion): nan P Value: 1.0
#
# ---------------------AIDS & ENTROPY-----------------
# Admin 1 - (HIV row count VOR, Entropy ): 0.17543009892 P Value: 0.472529630955
# Admin 2 - (HIV row count VOR, Entropy): -0.13169110778 P Value: 0.361967173823
# Admin 3 - (HIV row count VOR, Entropy): nan P Value: 1.0
#
# ---------------------AIDS & MED DEGREE-----------------
# Admin 1 - (HIV row count VOR, Med Degree): nan P Value: 1.0
# ...

# %%
# Computing Kendall correlation between the Child Mortality & (Activity, Network Advantage, Introversion)
cm_admin_1 = pd.read_csv(cm_path + "cm_vor_aggregate_1.csv")
cm_admin_2 = pd.read_csv(cm_path + "cm_vor_aggregate_2.csv")
cm_admin_3 = pd.read_csv(cm_path + "cm_vor_aggregate_3.csv")

# -------------------------------------NORMALISATION OF CHILD MORTALITY DATA -----------------------------------------------
cm_admin_1['CM_Row_Count'] = np.log(cm_admin_1['CM_Row_Count'])
aids_zscore_1 = cm_admin_1['CM_Row_Count'].values

cm_admin_2['CM_Row_Count'] = np.log(cm_admin_2['CM_Row_Count'])
aids_zscore_2 = cm_admin_2['CM_Row_Count'].values

cm_admin_3['CM_Row_Count'] = np.log(cm_admin_3['CM_Row_Count'])
aids_zscore_3 = cm_admin_3['CM_Row_Count'].values

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------CM & ACTIVITY-----------------")
x, y = stats.pearsonr(cm_admin_1['CM_Row_Count'], activity_admin_1['Activity'])
print("Admin 1 - (CM row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_2['CM_Row_Count'], activity_admin_2['Activity'])
print("Admin 2 - (CM row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_3['CM_Row_Count'], activity_admin_3['Activity'])
print("Admin 3 - (CM row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------CM & INTROVERSION-----------------")
x, y = stats.pearsonr(cm_admin_1['CM_Row_Count'], introversion_admin_1['avg_introversion'])
print("Admin 1 - (CM row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_2['CM_Row_Count'], introversion_admin_2['avg_introversion'])
print("Admin 2 - (CM row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_3['CM_Row_Count'], introversion_admin_3['avg_introversion'])
print("Admin 3 - (CM row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------CM & ENTROPY-----------------")
x, y = stats.pearsonr(cm_admin_1['CM_Row_Count'], entropy_admin_1['normalised_entropy'])
print("Admin 1 - (CM row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_2['CM_Row_Count'], entropy_admin_2['normalised_entropy'])
print("Admin 2 - (CM row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_3['CM_Row_Count'], entropy_admin_3['normalised_entropy'])
print("Admin 3 - (CM row count VOR, Entropy): " +  str(x) + " P Value: " + str(y) )
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------CM & MED DEGREE-----------------")
x, y = stats.pearsonr(cm_admin_1['CM_Row_Count'], meddegree_admin_1['medDegree'])
print("Admin 1 - (CM row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_2['CM_Row_Count'], meddegree_admin_2['medDegree'])
print("Admin 2 - (CM row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(cm_admin_3['CM_Row_Count'], meddegree_admin_3['medDegree'])
print("Admin 3 - (CM row count VOR, Med Degree): " +  str(x) + " P Value: " + str(y))
print()
# Out:
# ---------------------CM & ACTIVITY-----------------
# Admin 1 - (CM row count VOR, Activity): 0.0289386817108 P Value: 0.906383686282
# Admin 2 - (CM row count VOR, Activity): 0.243468904175 P Value: 0.0884212864562
# Admin 3 - (CM row count VOR, Activity): 0.234543056255 P Value: 0.00131149380222
#
# ---------------------CM & INTROVERSION-----------------
# Admin 1 - (CM row count VOR, Introversion): -0.0590506386788 P Value: 0.810229186367
# Admin 2 - (CM row count VOR, Introversion): -0.110193391423 P Value: 0.446178518777
# Admin 3 - (CM row count VOR, Introversion): nan P Value: 1.0
#
# ---------------------CM & ENTROPY-----------------
# Admin 1 - (CM row count VOR, Entropy ): 0.152988475868 P Value: 0.531782638786
# Admin 2 - (CM row count VOR, Entropy): -0.0545358758079 P Value: 0.706802846886
# Admin 3 - (CM row count VOR, Entropy): nan P Value: 1.0
#
# ---------------------CM & MED DEGREE-----------------
# Admin 1 - (CM row count VOR, Med Degree): nan P Value: 1.0
# ...

# %%
# Computing Kendall correlation between the Malaria & (Activity, Network Advantage, Introversion)
malaria_admin_1 = pd.read_csv(malaria_path + "malaria_vor_aggregate_1.csv")
malaria_admin_2 = pd.read_csv(malaria_path + "malaria_vor_aggregate_2.csv")
malaria_admin_3 = pd.read_csv(malaria_path + "malaria_vor_aggregate_3.csv")

# -------------------------------------------NORMALISATION OF MALARIA DATA -----------------------------------------------
malaria_admin_1['Lab_Row_Count'] = np.log(malaria_admin_1['Lab_Row_Count'])
aids_zscore_1 = malaria_admin_1['Lab_Row_Count'].values

malaria_admin_2['Lab_Row_Count'] = np.log(malaria_admin_2['Lab_Row_Count'])
aids_zscore_2 = malaria_admin_2['Lab_Row_Count'].values

malaria_admin_3['Lab_Row_Count'] = np.log(malaria_admin_3['Lab_Row_Count'])
aids_zscore_3 = malaria_admin_3['Lab_Row_Count'].values

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & ACTIVITY-----------------")
x, y = stats.pearsonr(malaria_admin_1['Lab_Row_Count'], activity_admin_1['Activity'])
print("Admin 1 - (Lab Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_admin_2['Lab_Row_Count'], activity_admin_2['Activity'])
print("Admin 2 - (Lab Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_admin_3['Lab_Row_Count'], activity_admin_3['Activity'])
print("Admin 3 - (Lab Test row count VOR, Activity): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & INTROVERSION-----------------")
x, y = stats.pearsonr(malaria_admin_1['Lab_Row_Count'], introversion_admin_1['avg_introversion'])
print("Admin 1 - (Lab Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_admin_2['Lab_Row_Count'], introversion_admin_2['avg_introversion'])
print("Admin 2 - (Lab Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_admin_3['Lab_Row_Count'], introversion_admin_3['avg_introversion'])
print("Admin 3 - (Lab Test row count VOR, Introversion): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & ENTROPY-----------------")
x, y = stats.pearsonr(malaria_admin_1['Lab_Row_Count'], entropy_admin_1['normalised_entropy'])
print("Admin 1 - (Lab Test row count VOR, Entropy ): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_admin_2['Lab_Row_Count'], entropy_admin_2['normalised_entropy'])
print("Admin 2 - (Lab Test row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))

x, y = stats.pearsonr(malaria_admin_3['Lab_Row_Count'], entropy_admin_3['normalised_entropy'])
print("Admin 3 - (Lab Test row count VOR, Entropy): " +  str(x) + " P Value: " + str(y))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------LAB TEST & MED DEGREE-----------------")
x, y = stats.pearsonr(malaria_admin_1['Lab_Row_Count'], meddegree_admin_1['medDegree'])
print("Admin 1 - (Lab Test row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(malaria_admin_2['Lab_Row_Count'], meddegree_admin_2['medDegree'])
print("Admin 2 - (Lab Test row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(malaria_admin_3['Lab_Row_Count'], meddegree_admin_3['medDegree'])
print("Admin 3 - (Lab Test row count VOR, Med Degree): " +  str(x))
print()
# Out:
# ---------------------LAB TEST & ACTIVITY-----------------
# Admin 1 - (Lab Test row count VOR, Activity): 0.366080610099 P Value: 0.123205127335
# Admin 2 - (Lab Test row count VOR, Activity): 0.345103455878 P Value: 0.0141099122482
# Admin 3 - (Lab Test row count VOR, Activity): nan P Value: 1.0
#
# ---------------------LAB TEST & INTROVERSION-----------------
# Admin 1 - (Lab Test row count VOR, Introversion): -0.148704810103 P Value: 0.543467415716
# Admin 2 - (Lab Test row count VOR, Introversion): 0.00151606701906 P Value: 0.991663003091
# Admin 3 - (Lab Test row count VOR, Introversion): nan P Value: 1.0
#
# ---------------------LAB TEST & ENTROPY-----------------
# Admin 1 - (Lab Test row count VOR, Entropy ): -0.15246788521 P Value: 0.533196479121
# Admin 2 - (Lab Test row count VOR, Entropy): -0.0770045825836 P Value: 0.595056509666
# Admin 3 - (Lab Test row count VOR, Entropy): nan P Value: 1.0
#
# ---------------------LAB TEST & MED DEGREE-----------------
# ...

# %%
# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & ACTIVITY-----------------")
x, y = stats.pearsonr(malaria_admin_1['Rapid_Row_Count'], activity_admin_1['Activity'])
print("Admin 1 - (Rapid Test row count VOR, Activity): " +  str(x))

x, y = stats.pearsonr(malaria_admin_2['Rapid_Row_Count'], activity_admin_2['Activity'])
print("Admin 2 - (Rapid Test row count VOR, Activity): " +  str(x))

x, y = stats.pearsonr(malaria_admin_3['Rapid_Row_Count'], activity_admin_3['Activity'])
print("Admin 3 - (Rapid Test row count VOR, Activity): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & INTROVERSION-----------------")
x, y = stats.pearsonr(malaria_admin_1['Rapid_Row_Count'], introversion_admin_1['avg_introversion'])
print("Admin 1 - (Rapid Test row count VOR, Introversion): " +  str(x))

x, y = stats.pearsonr(malaria_admin_2['Rapid_Row_Count'], introversion_admin_2['avg_introversion'])
print("Admin 2 - (Rapid Test row count VOR, Introversion): " +  str(x))

x, y = stats.pearsonr(malaria_admin_3['Rapid_Row_Count'], introversion_admin_3['avg_introversion'])
print("Admin 3 - (Rapid Test row count VOR, Introversion): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & ENTROPY-----------------")
x, y = stats.pearsonr(malaria_admin_1['Rapid_Row_Count'], entropy_admin_1['normalised_entropy'])
print("Admin 1 - (Rapid Test row count VOR, Entropy ): " +  str(x))

x, y = stats.pearsonr(malaria_admin_2['Rapid_Row_Count'], entropy_admin_2['normalised_entropy'])
print("Admin 2 - (Rapid Test row count VOR, Entropy): " +  str(x))

x, y = stats.pearsonr(malaria_admin_3['Rapid_Row_Count'], entropy_admin_3['normalised_entropy'])
print("Admin 3 - (Rapid Test row count VOR, Entropy): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------MALARIA RAPID TEST & MED DEGREE-----------------")
x, y = stats.pearsonr(malaria_admin_1['Rapid_Row_Count'], meddegree_admin_1['medDegree'])
print("Admin 1 - (Rapid Test row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(malaria_admin_2['Rapid_Row_Count'], meddegree_admin_2['medDegree'])
print("Admin 2 - (Rapid Test row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(malaria_admin_3['Rapid_Row_Count'], meddegree_admin_3['medDegree'])
print("Admin 3 - (Rapid Test row count VOR, Med Degree): " +  str(x))
print()
# Out:
# ---------------------RAPID TEST & ACTIVITY-----------------
# Admin 1 - (Lab Test row count VOR, Activity): 0.0709556674539
# Admin 2 - (Lab Test row count VOR, Activity): 0.226626614424
# Admin 3 - (Lab Test row count VOR, Activity): 0.316766259147
#
# ---------------------RAPID TEST & INTROVERSION-----------------
# Admin 1 - (Lab Test row count VOR, Introversion): 0.108396269373
# Admin 2 - (Lab Test row count VOR, Introversion): 0.0413976961416
# Admin 3 - (Lab Test row count VOR, Introversion): nan
#
# ---------------------RAPID TEST & ENTROPY-----------------
# Admin 1 - (Lab Test row count VOR, Entropy ): -0.308727749061
# Admin 2 - (Lab Test row count VOR, Entropy): -0.159340087218
# Admin 3 - (Lab Test row count VOR, Entropy): nan
#
# ---------------------RAPID TEST & MED DEGREE-----------------
# Admin 1 - (Lab Test row count VOR, Med Degree): 0.327002444306
# Admin 2 - (Lab Test row count VOR, Med Degree): 0.203943352462
# ...

# %%
# Computing Kendall correlation between the Womens' Access To Health & (Activity, Network Advantage, Introversion)
wha_admin_1 = pd.read_csv(wha_path + "wha_vor_aggregate_1.csv")
wha_admin_2 = pd.read_csv(wha_path + "wha_vor_aggregate_2.csv")
wha_admin_3 = pd.read_csv(wha_path + "wha_vor_aggregate_3.csv")

# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------WHA & ACTIVITY-----------------")
x, y = stats.pearsonr(wha_admin_1['Care_Row_Count'], activity_admin_1['Activity'])
print("Admin 1 - (WHA row count VOR, Activity): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Care_Row_Count'], activity_admin_2['Activity'])
print("Admin 2 - (WHA row count VOR, Activity): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Care_Row_Count'], activity_admin_3['Activity'])
print("Admin 3 - (WHA row count VOR, Activity): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA & INTROVERSION-----------------")
x, y = stats.pearsonr(wha_admin_1['Care_Row_Count'], introversion_admin_1['avg_introversion'])
print("Admin 1 - (WHA row count VOR, Introversion): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Care_Row_Count'], introversion_admin_2['avg_introversion'])
print("Admin 2 - (WHA row count VOR, Introversion): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Care_Row_Count'], introversion_admin_3['avg_introversion'])
print("Admin 3 - (WHA row count VOR, Introversion): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA & ENTROPY-----------------")
x, y = stats.pearsonr(wha_admin_1['Care_Row_Count'], entropy_admin_1['normalised_entropy'])
print("Admin 1 - (WHA row count VOR, Entropy ): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Care_Row_Count'], entropy_admin_2['normalised_entropy'])
print("Admin 2 - (WHA row count VOR, Entropy): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Care_Row_Count'], entropy_admin_3['normalised_entropy'])
print("Admin 3 - (WHA row count VOR, Entropy): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA & MED DEGREE-----------------")
x, y = stats.pearsonr(wha_admin_1['Care_Row_Count'], meddegree_admin_1['medDegree'])
print("Admin 1 - (WHA row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Care_Row_Count'], meddegree_admin_2['medDegree'])
print("Admin 2 - (WHA row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Care_Row_Count'], meddegree_admin_3['medDegree'])
print("Admin 3 - (WHA row count VOR, Med Degree): " +  str(x))
print()
# Out:
# ---------------------WHA & ACTIVITY-----------------
# Admin 1 - (WHA row count VOR, Activity): 0.79039353385
# Admin 2 - (WHA row count VOR, Activity): 0.882695955874
# Admin 3 - (WHA row count VOR, Activity): 0.888772918975
#
# ---------------------WHA & INTROVERSION-----------------
# Admin 1 - (WHA row count VOR, Introversion): -0.433176482989
# Admin 2 - (WHA row count VOR, Introversion): -0.274623895458
# Admin 3 - (WHA row count VOR, Introversion): nan
#
# ---------------------WHA & ENTROPY-----------------
# Admin 1 - (WHA row count VOR, Entropy ): 0.265635943748
# Admin 2 - (WHA row count VOR, Entropy): 0.104430567003
# Admin 3 - (WHA row count VOR, Entropy): nan
#
# ---------------------WHA & MED DEGREE-----------------
# Admin 1 - (WHA row count VOR, Med Degree): 0.369929503438
# Admin 2 - (WHA row count VOR, Med Degree): 0.243538106865
# Admin 3 - (WHA row count VOR, Med Degree): nan
# ...

# %%
# -------------------------------------------PEARSON R  CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & ACTIVITY-----------------")
x, y = stats.pearsonr(wha_admin_1['Zero_Row_Count'], activity_admin_1['Activity'])
print("Admin 1 - (WHA row count VOR, Activity): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Zero_Row_Count'], activity_admin_2['Activity'])
print("Admin 2 - (WHA row count VOR, Activity): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Zero_Row_Count'], activity_admin_3['Activity'])
print("Admin 3 - (WHA row count VOR, Activity): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & INTROVERSION-----------------")
x, y = stats.pearsonr(wha_admin_1['Zero_Row_Count'], introversion_admin_1['avg_introversion'])
print("Admin 1 - (WHA row count VOR, Introversion): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Zero_Row_Count'], introversion_admin_2['avg_introversion'])
print("Admin 2 - (WHA row count VOR, Introversion): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Zero_Row_Count'], introversion_admin_3['avg_introversion'])
print("Admin 3 - (WHA row count VOR, Introversion): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & ENTROPY-----------------")
x, y = stats.pearsonr(wha_admin_1['Zero_Row_Count'], entropy_admin_1['normalised_entropy'])
print("Admin 1 - (WHA row count VOR, Entropy ): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Zero_Row_Count'], entropy_admin_2['normalised_entropy'])
print("Admin 2 - (WHA row count VOR, Entropy): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Zero_Row_Count'], entropy_admin_3['normalised_entropy'])
print("Admin 3 - (WHA row count VOR, Entropy): " +  str(x))
print()

# -------------------------------------------PEARSON R CORRELATIONS-----------------------------------------------
print("---------------------WHA ZERO CARE & MED DEGREE-----------------")
x, y = stats.pearsonr(wha_admin_1['Zero_Row_Count'], meddegree_admin_1['medDegree'])
print("Admin 1 - (WHA row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(wha_admin_2['Zero_Row_Count'], meddegree_admin_2['medDegree'])
print("Admin 2 - (WHA row count VOR, Med Degree): " +  str(x))

x, y = stats.pearsonr(wha_admin_3['Zero_Row_Count'], meddegree_admin_3['medDegree'])
print("Admin 3 - (WHA row count VOR, Med Degree): " +  str(x))
print()
# Out:
# ---------------------WHA ZERO CARE & ACTIVITY-----------------
# Admin 1 - (WHA row count VOR, Activity): -0.106150980291
# Admin 2 - (WHA row count VOR, Activity): 0.0358662072338
# Admin 3 - (WHA row count VOR, Activity): 0.156603915345
#
# ---------------------WHA ZERO CARE & INTROVERSION-----------------
# Admin 1 - (WHA row count VOR, Introversion): 0.510564076874
# Admin 2 - (WHA row count VOR, Introversion): 0.298790206899
# Admin 3 - (WHA row count VOR, Introversion): nan
#
# ---------------------WHA ZERO CARE & ENTROPY-----------------
# Admin 1 - (WHA row count VOR, Entropy ): -0.0700649184652
# Admin 2 - (WHA row count VOR, Entropy): -0.0377996874597
# Admin 3 - (WHA row count VOR, Entropy): nan
#
# ---------------------WHA ZERO CARE & MED DEGREE-----------------
# Admin 1 - (WHA row count VOR, Med Degree): -0.44628214234
# Admin 2 - (WHA row count VOR, Med Degree): -0.324089884385
# Admin 3 - (WHA row count VOR, Med Degree): nan
# ...
