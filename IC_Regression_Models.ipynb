# %%
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pandas as pd
import numpy as np

# %%
# Cote D'Ivoire Files.
regression_dhs = "CDR_Data_IC/Regression/DHS/"
regression_cdr = "CDR_Data_IC/Regression/CDR/"

activity_admin_1 = pd.read_csv(regression_cdr + "activity_1.csv", index_col="Region")
activity_admin_2 = pd.read_csv(regression_cdr + "activity_2.csv", index_col="Region")
activity_admin_3 = pd.read_csv(regression_cdr + "activity_3.csv", index_col="Region")

introversion_admin_1 = pd.read_csv(regression_cdr + "introversion_1.csv", index_col="Region")
introversion_admin_2 = pd.read_csv(regression_cdr + "introversion_2.csv", index_col="Region")
introversion_admin_3 = pd.read_csv(regression_cdr + "introversion_3.csv", index_col="Region")

entropy_admin_1 = pd.read_csv(regression_cdr + "entropy_1.csv", index_col="Region")
entropy_admin_2 = pd.read_csv(regression_cdr + "entropy_2.csv", index_col="Region")
entropy_admin_3 = pd.read_csv(regression_cdr + "entropy_3.csv", index_col="Region")

meddegree_admin_1 = pd.read_csv(regression_cdr + "meddegree_1.csv", index_col="Region")
meddegree_admin_2 = pd.read_csv(regression_cdr + "meddegree_2.csv", index_col="Region")
meddegree_admin_3 = pd.read_csv(regression_cdr + "meddegree_3.csv", index_col="Region")

gresidual_1 = pd.read_csv(regression_cdr + "gresidual_1.csv", index_col="Region")
gresidual_2 = pd.read_csv(regression_cdr + "gresidual_2.csv", index_col="Region")
gresidual_3 = pd.read_csv(regression_cdr + "gresidual_3.csv", index_col="Region")

aids_admin_1 = pd.read_csv(regression_dhs + "aids_1.csv", index_col="Region")
aids_admin_2 = pd.read_csv(regression_dhs + "aids_2.csv", index_col="Region")
aids_admin_3 = pd.read_csv(regression_dhs + "aids_3.csv", index_col="Region")

child_mortality_1 = pd.read_csv(regression_dhs + "cm_1.csv", index_col="Region")
child_mortality_2 = pd.read_csv(regression_dhs + "cm_2.csv", index_col="Region")
child_mortality_3 = pd.read_csv(regression_dhs + "cm_3.csv", index_col="Region")

malaria_rapid_admin_1 = pd.read_csv(regression_dhs + "malaria_rapid_1.csv", index_col="Region")
malaria_rapid_admin_2 = pd.read_csv(regression_dhs + "malaria_rapid_2.csv", index_col="Region")
malaria_rapid_admin_3 = pd.read_csv(regression_dhs + "malaria_rapid_3.csv", index_col="Region")

malaria_lab_admin_1 = pd.read_csv(regression_dhs + "malaria_lab_1.csv", index_col="Region")
malaria_lab_admin_2 = pd.read_csv(regression_dhs + "malaria_lab_2.csv", index_col="Region")
malaria_lab_admin_3 = pd.read_csv(regression_dhs + "malaria_lab_3.csv", index_col="Region")

wha_care_admin_1 = pd.read_csv(regression_dhs + "wha_care_1.csv", index_col="Region")
wha_care_admin_2 = pd.read_csv(regression_dhs + "wha_care_2.csv", index_col="Region")
wha_care_admin_3 = pd.read_csv(regression_dhs + "wha_care_3.csv", index_col="Region")

wha_nocare_admin_1 = pd.read_csv(regression_dhs + "wha_nocare_1.csv", index_col="Region")
wha_nocare_admin_2 = pd.read_csv(regression_dhs + "wha_nocare_2.csv", index_col="Region")
wha_nocare_admin_3 = pd.read_csv(regression_dhs + "wha_nocare_3.csv", index_col="Region")

# %%
# Cote D'Ivoire OLS - Admin Region 1.
# Independent Variables
activity = activity_admin_1['Activity'].values
introversion = introversion_admin_1['avg_introversion'].values
norm_entropy = entropy_admin_1['normalised_entropy'].values
median_degree = meddegree_admin_1['medDegree'].values
gravity_residual = gresidual_1['gResidual'].values

# Dependent Variables.
y_aids_1 = aids_admin_1['Positive_HIV_Pop']
y_cm_1 = child_mortality_1['CM_Pop_Count']
y_malaria_rapid_1 = malaria_rapid_admin_1['Rapid_Pop_Count']
y_malalaria_lab_1 = malaria_lab_admin_1['Lab_Pop_Count']
y_wha_care_1 = wha_care_admin_1['Care_Pop_Count']
y_wha_nocare_1 = wha_nocare_admin_1['Zero_Pop_Count']


# -----------------------AIDS--------------------------------------
print("AIDS Admin 1 OLS Regression")
independent_var_admin_1 = np.column_stack((activity, gravity_residual + introversion, median_degree))
independent_var_admin_1 = sm.add_constant(independent_var_admin_1, prepend=True)

results_aids_1 = smf.OLS(y_aids_1,independent_var_admin_1).fit()
print(results_aids_1.summary())
print()

# -----------------------CM--------------------------------------
print("Child Mortality Admin 1 OLS Regression")
independent_var_admin_1 = np.column_stack((activity, gravity_residual, introversion))
independent_var_admin_1 = sm.add_constant(independent_var_admin_1, prepend=True)

results_cm_1 = smf.OLS(y_cm_1,independent_var_admin_1).fit()
print(results_cm_1.summary())
print()

# # -----------------------MALARIA RAPID--------------------------------------
print("Malaria Rapid Test Admin 1 OLS Regression")
independent_var_admin_1 = np.column_stack((activity, median_degree))
independent_var_admin_1 = sm.add_constant(independent_var_admin_1, prepend=True)

results_malaria_rapid_1 = smf.OLS(y_malaria_rapid_1,independent_var_admin_1).fit()
print(results_malaria_rapid_1.summary())
print()

# # -----------------------MALARIA LAB--------------------------------------
print("Malaria Lab Test Admin 1 OLS Regression")
independent_var_admin_1 = np.column_stack((activity, gravity_residual, median_degree))
independent_var_admin_1 = sm.add_constant(independent_var_admin_1, prepend=True)

results_malaria_lab_1 = smf.OLS(malaria_lab_admin_1,independent_var_admin_1).fit()
print(results_malaria_lab_1.summary())
print()

# # -----------------------WHA CARE--------------------------------------
print("Women's Access to Health Admin 1 OLS Regression")
independent_var_admin_1 = np.column_stack((activity, gravity_residual, introversion, median_degree))
independent_var_admin_1 = sm.add_constant(independent_var_admin_1, prepend=True)

results_wha_1 = smf.OLS(wha_care_admin_1,independent_var_admin_1).fit()
print(results_wha_1.summary())
print()

# # -----------------------WHA ZERO CARE--------------------------------------
print("Women's Access to Health (Zero Antenatal Care) Test Admin 1 OLS Regression")
independent_var_admin_1 = np.column_stack((activity, gravity_residual))
independent_var_admin_1 = sm.add_constant(independent_var_admin_1, prepend=True)

results_wha_nocare_1 = smf.OLS(wha_nocare_admin_1,independent_var_admin_1).fit()
print(results_wha_nocare_1.summary())
print()
# Out:
# AIDS Admin 1 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Positive_HIV_Pop   R-squared:                       0.639
# Model:                            OLS   Adj. R-squared:                  0.566
# Method:                 Least Squares   F-statistic:                     8.839
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):            0.00129
# Time:                        20:57:47   Log-Likelihood:                -17.288
# No. Observations:                  19   AIC:                             42.58
# Df Residuals:                      15   BIC:                             46.35
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.075e-16      0.155   1.98e-15      1.000      -0.331       0.331
# x1             0.5022      0.236      2.124      0.051      -0.002       1.006
# x2            -0.1163      0.132     -0.878      0.394      -0.399       0.166
# x3             0.2102      0.192      1.092      0.292      -0.200       0.621
# ==============================================================================
# Omnibus:                        6.979   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                4.369
# Skew:                           0.860   Prob(JB):                        0.113
# Kurtosis:                       4.600   Cond. No.                         3.32
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Child Mortality Admin 1 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           CM_Pop_Count   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                 -0.067
# Method:                 Least Squares   F-statistic:                    0.6236
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):              0.611
# Time:                        20:57:47   Log-Likelihood:                -25.843
# No. Observations:                  19   AIC:                             59.69
# Df Residuals:                      15   BIC:                             63.46
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.472e-19      0.243   3.07e-18      1.000      -0.519       0.519
# x1             0.3545      0.382      0.928      0.368      -0.460       1.169
# x2             0.1859      0.275      0.677      0.509      -0.400       0.771
# x3            -0.0220      0.379     -0.058      0.954      -0.830       0.786
# ==============================================================================
# Omnibus:                        1.110   Durbin-Watson:                   2.363
# Prob(Omnibus):                  0.574   Jarque-Bera (JB):                0.832
# Skew:                           0.482   Prob(JB):                        0.660
# Kurtosis:                       2.651   Cond. No.                         2.96
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Malaria Rapid Test Admin 1 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Rapid_Pop_Count   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.269
# Method:                 Least Squares   F-statistic:                     4.307
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):             0.0319
# Time:                        20:57:47   Log-Likelihood:                -22.868
# No. Observations:                  19   AIC:                             51.74
# Df Residuals:                      16   BIC:                             54.57
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.996e-17      0.202  -3.97e-16      1.000      -0.427       0.427
# x1            -0.2351      0.247     -0.953      0.355      -0.758       0.288
# x2             0.6949      0.247      2.818      0.012       0.172       1.218
# ==============================================================================
# Omnibus:                       16.693   Durbin-Watson:                   2.303
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.580
# Skew:                           1.599   Prob(JB):                     0.000152
# Kurtosis:                       6.462   Cond. No.                         1.93
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Malaria Lab Test Admin 1 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lab_Pop_Count   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     5.537
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):            0.00922
# Time:                        20:57:47   Log-Likelihood:                -19.878
# No. Observations:                  19   AIC:                             47.76
# Df Residuals:                      15   BIC:                             51.53
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.597e-18      0.178   2.58e-17      1.000      -0.379       0.379
# x1            -0.2923      0.228     -1.283      0.219      -0.778       0.193
# x2            -0.1247      0.201     -0.620      0.545      -0.553       0.304
# x3             0.8077      0.221      3.658      0.002       0.337       1.278
# ==============================================================================
# Omnibus:                        3.290   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.193   Jarque-Bera (JB):                1.417
# Skew:                           0.299   Prob(JB):                        0.492
# Kurtosis:                       4.197   Cond. No.                         2.15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Women's Access to Health Admin 1 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Care_Pop_Count   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.427
# Method:                 Least Squares   F-statistic:                     4.354
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):             0.0170
# Time:                        20:57:47   Log-Likelihood:                -19.281
# No. Observations:                  19   AIC:                             48.56
# Df Residuals:                      14   BIC:                             53.28
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.096e-16      0.178   6.14e-16      1.000      -0.383       0.383
# x1             0.4563      0.299      1.527      0.149      -0.185       1.097
# x2            -0.0893      0.204     -0.438      0.668      -0.527       0.348
# x3            -0.1140      0.278     -0.410      0.688      -0.710       0.482
# x4             0.2190      0.222      0.988      0.340      -0.256       0.694
# ==============================================================================
# Omnibus:                       19.712   Durbin-Watson:                   2.388
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.224
# Skew:                           1.736   Prob(JB):                     3.33e-06
# Kurtosis:                       7.451   Cond. No.                         3.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Women's Access to Health (Zero Antenatal Care) Test Admin 1 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Zero_Pop_Count   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.8240
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):              0.456
# Time:                        20:57:47   Log-Likelihood:                -26.028
# No. Observations:                  19   AIC:                             58.06
# Df Residuals:                      16   BIC:                             60.89
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.607e-16      0.238    1.1e-15      1.000      -0.505       0.505
# x1            -0.0186      0.265     -0.070      0.945      -0.581       0.544
# x2             0.2969      0.265      1.119      0.280      -0.266       0.859
# ==============================================================================
# Omnibus:                        0.302   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.860   Jarque-Bera (JB):                0.005
# Skew:                           0.027   Prob(JB):                        0.997
# Kurtosis:                       2.938   Cond. No.                         1.61
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.6/site-packages/scipy/stats/stats.py:1390: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   "anyway, n=%i" % int(n))

# %%
# Cote D'Ivoire OLS - Admin Region 2.
# Independent Variables
activity = activity_admin_2['Activity'].values
introversion = introversion_admin_2['avg_introversion'].values
norm_entropy = entropy_admin_2['normalised_entropy'].values
median_degree = meddegree_admin_2['medDegree'].values
gravity_residual = gresidual_2['gResidual'].values

# Dependent Variables.
y_aids_2 = aids_admin_2['Positive_HIV_Pop']
y_cm_2 = child_mortality_2['CM_Pop_Count']
y_malaria_rapid_2 = malaria_rapid_admin_2['Rapid_Pop_Count']
y_malalaria_lab_2 = malaria_lab_admin_2['Lab_Pop_Count']
y_wha_care_2 = wha_care_admin_2['Care_Pop_Count']
y_wha_nocare_2 = wha_nocare_admin_2['Zero_Pop_Count']

# -----------------------AIDS--------------------------------------
print("AIDS Admin 2 OLS Regression")
independent_var_admin_2 = np.column_stack((activity, gravity_residual, introversion, median_degree))
independent_var_admin_2 = sm.add_constant(independent_var_admin_2, prepend=True)

results_aids_2 = smf.OLS(y_aids_2,independent_var_admin_2).fit()
print(results_aids_2.summary())
print()

# -----------------------CM--------------------------------------
print("Child Mortality Admin 2 OLS Regression")
independent_var_admin_2 = np.column_stack((activity, gravity_residual, introversion))
independent_var_admin_2 = sm.add_constant(independent_var_admin_2, prepend=True)


results_cm_2 = smf.OLS(y_cm_2,independent_var_admin_2).fit()
print(results_cm_2.summary())
print()

# -----------------------MALARIA RAPID--------------------------------------
print("Malaria Rapid Test Admin 2 OLS Regression")
independent_var_admin_2 = np.column_stack((activity, median_degree))
independent_var_admin_2 = sm.add_constant(independent_var_admin_2, prepend=True)


results_malaria_rapid_2 = smf.OLS(y_malaria_rapid_2,independent_var_admin_2).fit()
print(results_malaria_rapid_2.summary())
print()

# -----------------------MALARIA LAB--------------------------------------
print("Malaria Lab Test Admin 2 OLS Regression")
independent_var_admin_2 = np.column_stack((activity, gravity_residual, median_degree))
independent_var_admin_2 = sm.add_constant(independent_var_admin_2, prepend=True)

results_malaria_lab_2 = smf.OLS(malaria_lab_admin_2,independent_var_admin_2).fit()
print(results_malaria_lab_2.summary())
print()

# -----------------------WHA NO CARE--------------------------------------
print("Women's Access to Health Admin 2 OLS Regression")
independent_var_admin_2 = np.column_stack((activity, gravity_residual, introversion, median_degree))
independent_var_admin_2 = sm.add_constant(independent_var_admin_2, prepend=True)


results_wha_2 = smf.OLS(wha_care_admin_2,independent_var_admin_2).fit()
print(results_wha_2.summary())
print()

# -----------------------WHA ZERO CARE--------------------------------------
print("Women's Access to Health Admin (Zero Antenatal Care) 2 OLS Regression")
independent_var_admin_2 = np.column_stack((activity, gravity_residual))
independent_var_admin_2 = sm.add_constant(independent_var_admin_2, prepend=True)

results_wha_nocare_2 = smf.OLS(wha_nocare_admin_2,independent_var_admin_2).fit()
print(results_wha_nocare_2.summary())
print()
# Out:
# AIDS Admin 2 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Positive_HIV_Pop   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.470
# Method:                 Least Squares   F-statistic:                     11.88
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           1.14e-06
# Time:                        20:57:47   Log-Likelihood:                -52.930
# No. Observations:                  50   AIC:                             115.9
# Df Residuals:                      45   BIC:                             125.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.163e-16      0.104      4e-15      1.000      -0.209       0.209
# x1             0.4320      0.132      3.282      0.002       0.167       0.697
# x2            -0.0172      0.137     -0.126      0.901      -0.293       0.259
# x3            -0.1843      0.123     -1.499      0.141      -0.432       0.063
# x4             0.2765      0.136      2.034      0.048       0.003       0.550
# ==============================================================================
# Omnibus:                        7.706   Durbin-Watson:                   1.726
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                7.821
# Skew:                           0.607   Prob(JB):                       0.0200
# Kurtosis:                       4.509   Cond. No.                         2.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Child Mortality Admin 2 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           CM_Pop_Count   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.178
# Method:                 Least Squares   F-statistic:                     4.539
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):            0.00720
# Time:                        20:57:47   Log-Likelihood:                -64.464
# No. Observations:                  50   AIC:                             136.9
# Df Residuals:                      46   BIC:                             144.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.776e-16      0.130  -2.14e-15      1.000      -0.261       0.261
# x1             0.4444      0.158      2.816      0.007       0.127       0.762
# x2             0.2553      0.144      1.769      0.084      -0.035       0.546
# x3            -0.1439      0.152     -0.947      0.348      -0.450       0.162
# ==============================================================================
# Omnibus:                        2.866   Durbin-Watson:                   1.529
# Prob(Omnibus):                  0.239   Jarque-Bera (JB):                2.433
# Skew:                           0.427   Prob(JB):                        0.296
# Kurtosis:                       2.337   Cond. No.                         1.96
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Malaria Rapid Test Admin 2 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Rapid_Pop_Count   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.230
# Method:                 Least Squares   F-statistic:                     8.324
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           0.000804
# Time:                        20:57:47   Log-Likelihood:                -63.367
# No. Observations:                  50   AIC:                             132.7
# Df Residuals:                      47   BIC:                             138.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.804e-16      0.125  -1.44e-15      1.000      -0.252       0.252
# x1            -0.0002      0.139     -0.002      0.999      -0.279       0.279
# x2             0.5115      0.139      3.689      0.001       0.233       0.790
# ==============================================================================
# Omnibus:                        8.639   Durbin-Watson:                   1.478
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                7.827
# Skew:                           0.834   Prob(JB):                       0.0200
# Kurtosis:                       3.986   Cond. No.                         1.58
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Malaria Lab Test Admin 2 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lab_Pop_Count   R-squared:                       0.312
# Model:                            OLS   Adj. R-squared:                  0.267
# Method:                 Least Squares   F-statistic:                     6.941
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           0.000597
# Time:                        20:57:47   Log-Likelihood:                -61.612
# No. Observations:                  50   AIC:                             131.2
# Df Residuals:                      46   BIC:                             138.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.022e-16      0.122  -4.11e-15      1.000      -0.246       0.246
# x1            -0.0950      0.139     -0.684      0.497      -0.374       0.184
# x2            -0.0835      0.158     -0.529      0.600      -0.401       0.234
# x3             0.5398      0.159      3.403      0.001       0.221       0.859
# ==============================================================================
# Omnibus:                        0.224   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.894   Jarque-Bera (JB):                0.423
# Skew:                          -0.009   Prob(JB):                        0.809
# Kurtosis:                       2.550   Cond. No.                         2.24
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Women's Access to Health Admin 2 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Care_Pop_Count   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.512
# Method:                 Least Squares   F-statistic:                     13.84
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           1.95e-07
# Time:                        20:57:47   Log-Likelihood:                -50.898
# No. Observations:                  50   AIC:                             111.8
# Df Residuals:                      45   BIC:                             121.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        4.58e-16      0.100   4.59e-15      1.000      -0.201       0.201
# x1             0.4605      0.126      3.644      0.001       0.206       0.715
# x2            -0.0208      0.131     -0.158      0.875      -0.286       0.244
# x3            -0.1914      0.118     -1.621      0.112      -0.429       0.046
# x4             0.2670      0.131      2.045      0.047       0.004       0.530
# ==============================================================================
# Omnibus:                       13.456   Durbin-Watson:                   1.453
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.579
# Skew:                           1.090   Prob(JB):                     0.000683
# Kurtosis:                       4.499   Cond. No.                         2.54
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Women's Access to Health Admin (Zero Antenatal Care) 2 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Zero_Pop_Count   R-squared:                       0.127
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     3.415
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):             0.0412
# Time:                        20:57:47   Log-Likelihood:                -67.555
# No. Observations:                  50   AIC:                             141.1
# Df Residuals:                      47   BIC:                             146.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.482e-16      0.136   4.02e-15      1.000      -0.274       0.274
# x1             0.2333      0.150      1.554      0.127      -0.069       0.535
# x2             0.3842      0.150      2.559      0.014       0.082       0.686
# ==============================================================================
# Omnibus:                        1.840   Durbin-Watson:                   1.728
# Prob(Omnibus):                  0.398   Jarque-Bera (JB):                1.222
# Skew:                          -0.051   Prob(JB):                        0.543
# Kurtosis:                       2.241   Cond. No.                         1.56
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Cote D'Ivoire OLS - Admin Region 3.
# Independent Variables
activity = activity_admin_3['Activity'].values 
introversion = introversion_admin_3['avg_introversion'].values
norm_entropy = entropy_admin_3['normalised_entropy'].values
median_degree = meddegree_admin_3['medDegree'].values
gravity_residual = gresidual_3['gResidual'].values

# Dependent Variables.
y_aids_3 = aids_admin_3['Positive_HIV_Pop']
y_cm_3 = child_mortality_3['CM_Pop_Count']
y_malaria_rapid_3 = malaria_rapid_admin_3['Rapid_Pop_Count']
y_malalaria_lab_3 = malaria_lab_admin_3['Lab_Pop_Count']
y_wha_care_3 = wha_care_admin_3['Care_Pop_Count']
y_wha_nocare_3 = wha_nocare_admin_3['Zero_Pop_Count']
# # -----------------------AIDS--------------------------------------
print("AIDS Admin 3 OLS Regression")
independent_var_admin_3 = np.column_stack((activity, gravity_residual, introversion, median_degree))
independent_var_admin_3 = sm.add_constant(independent_var_admin_3, prepend=True)


results_aids_3 = smf.OLS(y_aids_3,independent_var_admin_3).fit()
print(results_aids_3.summary())
print()

# -----------------------CM--------------------------------------
print("Child Mortality Admin 3 OLS Regression")
independent_var_admin_3 = np.column_stack((activity, gravity_residual, introversion))
independent_var_admin_3 = sm.add_constant(independent_var_admin_3, prepend=True)

results_cm_3 = smf.OLS(y_cm_3,independent_var_admin_3).fit()
print(results_cm_3.summary())
print()

# # -----------------------MALARIA RAPID--------------------------------------
print("Malaria Rapid Test Admin 3 OLS Regression")
independent_var_admin_3 = np.column_stack((activity, median_degree))
independent_var_admin_3 = sm.add_constant(independent_var_admin_3, prepend=True)

results_malaria_rapid_3 = smf.OLS(y_malaria_rapid_3,independent_var_admin_3).fit()
print(results_malaria_rapid_3.summary())
print()


# # -----------------------MALARIA LAB--------------------------------------
print("Malaria Lab Test Admin 3 OLS Regression")
independent_var_admin_3 = np.column_stack((activity, gravity_residual, median_degree))
independent_var_admin_3 = sm.add_constant(independent_var_admin_3, prepend=True)

results_malaria_lab_3 = smf.OLS(malaria_lab_admin_3,independent_var_admin_3).fit()
print(results_malaria_lab_3.summary())
print()


# -----------------------WHA NO CARE--------------------------------------
print("Women's Access to Health Admin 3 OLS Regression")
independent_var_admin_3 = np.column_stack((activity, gravity_residual, introversion, median_degree))
independent_var_admin_3 = sm.add_constant(independent_var_admin_3, prepend=True)

results_wha_3 = smf.OLS(wha_care_admin_3,independent_var_admin_3).fit()
print(results_wha_3.summary())
print()


# -----------------------WHA ZERO CARE--------------------------------------
print("Women's Access to Health Admin (Zero Antenatal Care) 3 OLS Regression")
independent_var_admin_3 = np.column_stack((activity, gravity_residual))
independent_var_admin_3 = sm.add_constant(independent_var_admin_3, prepend=True)

results_wha_nocare_3 = smf.OLS(wha_nocare_admin_3, independent_var_admin_3).fit()
print(results_wha_nocare_3.summary())
print()
# Out:
# AIDS Admin 3 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Positive_HIV_Pop   R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     58.70
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           1.22e-31
# Time:                        20:57:48   Log-Likelihood:                -185.28
# No. Observations:                 185   AIC:                             380.6
# Df Residuals:                     180   BIC:                             396.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.859e-17      0.049  -3.79e-16      1.000      -0.097       0.097
# x1             0.7456      0.064     11.563      0.000       0.618       0.873
# x2            -0.0797      0.056     -1.417      0.158      -0.191       0.031
# x3            -0.0777      0.074     -1.050      0.295      -0.224       0.068
# x4            -0.0576      0.079     -0.730      0.466      -0.213       0.098
# ==============================================================================
# Omnibus:                       41.827   Durbin-Watson:                   1.734
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              100.544
# Skew:                           0.981   Prob(JB):                     1.47e-22
# Kurtosis:                       6.033   Cond. No.                         2.98
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Child Mortality Admin 3 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           CM_Pop_Count   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     16.45
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           1.70e-09
# Time:                        20:57:48   Log-Likelihood:                -240.20
# No. Observations:                 185   AIC:                             488.4
# Df Residuals:                     181   BIC:                             501.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        4.77e-17      0.066   7.24e-16      1.000      -0.130       0.130
# x1             0.4038      0.067      6.011      0.000       0.271       0.536
# x2            -0.0255      0.075     -0.341      0.733      -0.173       0.122
# x3            -0.1908      0.073     -2.598      0.010      -0.336      -0.046
# ==============================================================================
# Omnibus:                       30.925   Durbin-Watson:                   0.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.235
# Skew:                           0.976   Prob(JB):                     4.09e-10
# Kurtosis:                       4.341   Cond. No.                         1.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Malaria Rapid Test Admin 3 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Rapid_Pop_Count   R-squared:                       0.208
# Model:                            OLS   Adj. R-squared:                  0.200
# Method:                 Least Squares   F-statistic:                     23.93
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           5.93e-10
# Time:                        20:57:48   Log-Likelihood:                -240.91
# No. Observations:                 185   AIC:                             487.8
# Df Residuals:                     182   BIC:                             497.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8.956e-17      0.066  -1.36e-15      1.000      -0.130       0.130
# x1             0.4638      0.077      6.050      0.000       0.313       0.615
# x2            -0.0151      0.077     -0.197      0.844      -0.166       0.136
# ==============================================================================
# Omnibus:                       36.047   Durbin-Watson:                   1.234
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.307
# Skew:                           0.979   Prob(JB):                     1.79e-14
# Kurtosis:                       5.093   Cond. No.                         1.75
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Malaria Lab Test Admin 3 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Lab_Pop_Count   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.182
# Method:                 Least Squares   F-statistic:                     14.62
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           1.44e-08
# Time:                        20:57:48   Log-Likelihood:                -242.43
# No. Observations:                 185   AIC:                             492.9
# Df Residuals:                     181   BIC:                             505.7
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.752e-16      0.067  -2.63e-15      1.000      -0.132       0.132
# x1             0.3931      0.080      4.888      0.000       0.234       0.552
# x2            -0.0547      0.069     -0.787      0.432      -0.192       0.082
# x3             0.0645      0.079      0.814      0.417      -0.092       0.221
# ==============================================================================
# Omnibus:                       19.238   Durbin-Watson:                   1.263
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.100
# Skew:                           0.689   Prob(JB):                     5.85e-06
# Kurtosis:                       4.108   Cond. No.                         1.89
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Women's Access to Health Admin 3 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Care_Pop_Count   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.627
# Method:                 Least Squares   F-statistic:                     78.37
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           2.21e-38
# Time:                        20:57:48   Log-Likelihood:                -169.22
# No. Observations:                 185   AIC:                             348.4
# Df Residuals:                     180   BIC:                             364.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.994e-16      0.045   4.43e-15      1.000      -0.089       0.089
# x1             0.8261      0.059     13.974      0.000       0.709       0.943
# x2            -0.1802      0.052     -3.495      0.001      -0.282      -0.078
# x3             0.0490      0.068      0.722      0.471      -0.085       0.183
# x4            -0.1866      0.072     -2.579      0.011      -0.329      -0.044
# ==============================================================================
# Omnibus:                       27.842   Durbin-Watson:                   1.445
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.667
# Skew:                           0.744   Prob(JB):                     6.03e-12
# Kurtosis:                       5.119   Cond. No.                         2.98
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Women's Access to Health Admin (Zero Antenatal Care) 3 OLS Regression
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Zero_Pop_Count   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     5.677
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):            0.00406
# Time:                        20:57:48   Log-Likelihood:                -256.91
# No. Observations:                 185   AIC:                             519.8
# Df Residuals:                     182   BIC:                             529.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.527e-16      0.072  -2.12e-15      1.000      -0.142       0.142
# x1             0.2122      0.073      2.898      0.004       0.068       0.357
# x2             0.1636      0.073      2.234      0.027       0.019       0.308
# ==============================================================================
# Omnibus:                       10.959   Durbin-Watson:                   1.262
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.171
# Skew:                           0.576   Prob(JB):                      0.00375
# Kurtosis:                       3.352   Cond. No.                         1.21
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
